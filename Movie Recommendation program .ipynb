# %%
import numpy as np
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
columns_name=['user_id','item_id','rating','timestamp']
df=pd.read_csv('u.data',sep="\t",names=columns_name)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
df.shape
# Out:
# (100000, 4)

# %%
df['user_id']
# Out:
# 0        196
# 1        186
# 2         22
# 3        244
# 4        166
#         ...
# 99995    880
# 99996    716
# 99997    276
# 99998     13
# 99999     12
# Name: user_id, Length: 100000, dtype: int64

# %%
df['user_id'].nunique()
# Out:
# 943

# %%
df['item_id'].nunique()
# Out:
# 1682

# %%
movies_title=pd.read_csv('u.item',sep="\|",header=None)

# %%
movies_title.shape
# Out:
# (1682, 24)

# %%
movies_titles=movies_title[[0,1]]
movies_titles.columns=["item_id","title"]
movies_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df=pd.merge(df,movies_titles,on="item_id")

# %%
df
# Out:
#        user_id  item_id  rating  timestamp  \
# 0          196      242       3  881250949
# 1           63      242       3  875747190
# 2          226      242       5  883888671
# 3          154      242       3  879138235
# 4          306      242       5  876503793
# ...        ...      ...     ...        ...
# 99995      840     1674       4  891211682
# 99996      655     1640       3  888474646
# 99997      655     1637       3  888984255
# 99998      655     1630       3  887428735
# 99999      655     1641       3  887427810
#
#                                                    title
# 0                                           Kolya (1996)
# 1                                           Kolya (1996)
# 2                                           Kolya (1996)
# 3                                           Kolya (1996)
# 4                                           Kolya (1996)
# ...                                                  ...
# ...

# %%
df.tail()
# Out:
#        user_id  item_id  rating  timestamp  \
# 99995      840     1674       4  891211682
# 99996      655     1640       3  888474646
# 99997      655     1637       3  888984255
# 99998      655     1630       3  887428735
# 99999      655     1641       3  887427810
#
#                                                    title
# 99995                                  Mamma Roma (1962)
# 99996                             Eighth Day, The (1996)
# 99997                                  Girls Town (1996)
# 99998  Silence of the Palace, The (Saimt el Qusur) (1...
# 99999                                    Dadetown (1995)

# %%
ratings=pd.DataFrame(df.groupby('title').mean()['rating'])

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['num of ratings']=pd.DataFrame(df.groupby('title').count()['rating'])

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp         title
# 0      196      242       3  881250949  Kolya (1996)
# 1       63      242       3  875747190  Kolya (1996)
# 2      226      242       5  883888671  Kolya (1996)
# 3      154      242       3  879138235  Kolya (1996)
# 4      306      242       5  876503793  Kolya (1996)

# %%
moviemat=df.pivot_table(index="user_id",columns="title",values="rating")

# %%
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
kolya_user_ratings=moviemat['Kolya (1996)']

# %%
youngguns_user_ratings.head(20)
# Out:
# user_id
# 1     3.0
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     3.0
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    3.0
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# Name: Young Guns (1988), dtype: float64

# %%
similar_to_kolya=moviemat.corrwith(kolya_user_ratings)

# %%
similar_to_kolya
# Out:
# title
# 'Til There Was You (1997)                     NaN
# 1-900 (1994)                                  NaN
# 101 Dalmatians (1996)                   -0.175412
# 12 Angry Men (1957)                      0.202548
# 187 (1997)                               0.455111
#                                            ...
# Young Guns II (1990)                          NaN
# Young Poisoner's Handbook, The (1995)    0.654129
# Zeus and Roxanne (1997)                 -1.000000
# unknown                                  1.000000
# Á köldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
corr_kolya=pd.DataFrame(similar_to_kolya,columns=['correlation'])

# %%
corr_kolya.dropna(inplace=True)

# %%
corr_youngguns
# Out:
#                                        correlation
# title
# 101 Dalmatians (1996)                     0.119234
# 12 Angry Men (1957)                       0.068944
# 187 (1997)                               -0.500000
# 2 Days in the Valley (1996)               0.156220
# 20,000 Leagues Under the Sea (1954)      -0.010894
# ...                                            ...
# Year of the Horse (1997)                  1.000000
# Young Frankenstein (1974)                 0.510284
# Young Guns (1988)                         1.000000
# Young Guns II (1990)                      0.722460
# Young Poisoner's Handbook, The (1995)    -0.019672
#
# [1162 rows x 1 columns]

# %%
corr_kolya.head()
# Out:
#                                      correlation
# title
# 101 Dalmatians (1996)                  -0.175412
# 12 Angry Men (1957)                     0.202548
# 187 (1997)                              0.455111
# 2 Days in the Valley (1996)             0.813117
# 20,000 Leagues Under the Sea (1954)     0.431818

# %%
corr_kolya.sort_values('correlation',ascending=False).head(10)
# Out:
#                                                     correlation
# title
# Late Bloomers (1996)                                        1.0
# Awfully Big Adventure, An (1995)                            1.0
# Open Season (1996)                                          1.0
# Wild Reeds (1994)                                           1.0
# Thin Line Between Love and Hate, A (1996)                   1.0
# Gang Related (1997)                                         1.0
# Palookaville (1996)                                         1.0
# Talking About Sex (1994)                                    1.0
# Forbidden Christ, The (Cristo proibito, Il) (1950)          1.0
# Poetic Justice (1993)                                       1.0

# %%
ratings
# Out:
#                                          rating  num of ratings
# title
# 'Til There Was You (1997)              2.333333               9
# 1-900 (1994)                           2.600000               5
# 101 Dalmatians (1996)                  2.908257             109
# 12 Angry Men (1957)                    4.344000             125
# 187 (1997)                             3.024390              41
# ...                                         ...             ...
# Young Guns II (1990)                   2.772727              44
# Young Poisoner's Handbook, The (1995)  3.341463              41
# Zeus and Roxanne (1997)                2.166667               6
# unknown                                3.444444               9
# Á köldum klaka (Cold Fever) (1994)     3.000000               1
#
# [1664 rows x 2 columns]

# %%
corr_kolya=corr_kolya.join(ratings['num of ratings'])

# %%
corr_kolya
# Out:
#                                        correlation  num of ratings
# title
# 101 Dalmatians (1996)                    -0.175412             109
# 12 Angry Men (1957)                       0.202548             125
# 187 (1997)                                0.455111              41
# 2 Days in the Valley (1996)               0.813117              93
# 20,000 Leagues Under the Sea (1954)       0.431818              72
# ...                                            ...             ...
# Young Frankenstein (1974)                 0.135613             200
# Young Guns (1988)                         0.115163             101
# Young Poisoner's Handbook, The (1995)     0.654129              41
# Zeus and Roxanne (1997)                  -1.000000               6
# unknown                                   1.000000               9
#
# [1152 rows x 2 columns]

# %%
corr_kolya.head()
# Out:
#                                      correlation  num of ratings
# title
# 101 Dalmatians (1996)                  -0.175412             109
# 12 Angry Men (1957)                     0.202548             125
# 187 (1997)                              0.455111              41
# 2 Days in the Valley (1996)             0.813117              93
# 20,000 Leagues Under the Sea (1954)     0.431818              72

# %%
corr_kolya[corr_kolya['num of ratings']>100].sort_values('correlation',ascending=False)
# Out:
#                                     correlation  num of ratings
# title
# Kolya (1996)                           1.000000             117
# Happy Gilmore (1996)                   0.739950             149
# Kingpin (1996)                         0.704529             162
# Alien: Resurrection (1997)             0.701990             124
# What's Eating Gilbert Grape (1993)     0.646358             115
# ...                                         ...             ...
# Die Hard: With a Vengeance (1995)     -0.382451             151
# Blues Brothers, The (1980)            -0.412643             251
# Batman Forever (1995)                 -0.413449             114
# Stargate (1994)                       -0.669289             127
# Batman Returns (1992)                 -0.684695             142
#
# [334 rows x 2 columns]

# %%
def predict_movies(movie_name):
    movie_user_ratings=moviemat[movie_name]
    similar_to_movie=moviemat.corrwith(movie_user_ratings)
    corr_movie=pd.DataFrame(similar_to_movie,columns=['correlation'])
    corr_movie.dropna(inplace=True)
    corr_movie=corr_movie.join(ratings['num of ratings'])
    
    predictions=corr_movie[corr_movie['num of ratings']>100].sort_values('correlation',ascending=False)
    
    return predictions

# %%
predict_my_movie=predict_movies("Alien: Resurrection (1997)")

# %%
predict_my_movie.head()
# Out:
#                                 correlation  num of ratings
# title
# 101 Dalmatians (1996)              1.000000             109
# Murder at 1600 (1997)              0.663965             218
# Miracle on 34th Street (1994)      0.609938             101
# Being There (1979)                 0.530438             116
# Remains of the Day, The (1993)     0.514223             150
